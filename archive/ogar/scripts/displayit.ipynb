# %%
from IPython.display import Image, display

# %%
from ogar.runtime.graph import build_ogar_graph

app = build_ogar_graph()
state_graph = app.get_graph(xray=True)

display(Image(state_graph.draw_mermaid_png()))
